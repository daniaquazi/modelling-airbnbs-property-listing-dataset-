# %%
import torch

# %%
from torchvision.datasets import MNIST
dataset=MNIST(root='./data', download=True, train=True)
example=dataset[45]
print(example)
features, label = example
print(features)
print(label)
features.show()
# Out:
# (<PIL.Image.Image image mode=L size=28x28 at 0x7F7A398A81C0>, 9)
# <PIL.Image.Image image mode=L size=28x28 at 0x7F7A398A81C0>
# 9

# %%
import pandas as pd
from torch.utils.data import Dataset
import torch
import numpy as np

class AirbnbNightlyPriceImageDataset(Dataset):
    def __init__(self):
        super().__init__()
        self.data = pd.read_csv("/Users/dq/Documents/aicore_project/Airbnb_Project/AirBnbData.csv")
        self.data.dropna(subset=['bedrooms'], inplace=True)
        self.data.pop("ID")
        self.data.pop("Category")
        self.data.pop("Title")
        self.data.pop("Description")
        self.data.pop("Amenities")
        self.data.pop("Location")
        self.data.pop("url")
        

    def __getitem__(self, index):
        example = self.data.iloc[index]
        features = example[1:10]
        features=torch.tensor(features)
        label = torch.tensor(example['Price_Night'])
        return (features, label)

    def __len__(self):
        return len(self.data)

dataset = AirbnbNightlyPriceImageDataset()

# %%
from torch.utils.data import DataLoader, random_split

train, test = random_split(dataset, [round(len(dataset)*0.8), round(len(dataset)*0.2)])
train, valid = random_split(dataset, [round(len(dataset)*0.75), round(len(dataset)*0.25)])

train_loader = DataLoader(train, batch_size=16, shuffle=True)
test_loader = DataLoader(test, batch_size=16, shuffle=True)
valid_loader = DataLoader(valid, batch_size=16, shuffle=True)

# %%
import torch.nn.functional as F

class LinearRegression(torch.nn.Module):
    def __init__(self)->None:
        super().__init__()
        #initialise parameters
        self.linear_layer=torch.nn.Linear(9,1)
        self.double()
        
    def forward(self, features):
        return self.linear_layer(features)

def train(model, epochs=10):
    optimiser = torch.optim.SGD(model.parameters(), lr=0.01)
    for epoch in range(epochs):
        for batch in train_loader:
            features, labels = batch
            prediction = model(features)
            loss = F.mse_loss(prediction, labels)
            loss.backward()
            print(loss.item())
            optimiser.step()
            optimiser.zero_grad()

model = LinearRegression()
train(model, epochs=5)
# Out:
# /var/folders/2j/d77yjnh176bbf7pmhw8lt2zc0000gq/T/ipykernel_4159/529532476.py:19: UserWarning: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([16, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss = F.mse_loss(prediction, labels)
# /var/folders/2j/d77yjnh176bbf7pmhw8lt2zc0000gq/T/ipykernel_4159/529532476.py:19: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss = F.mse_loss(prediction, labels)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
